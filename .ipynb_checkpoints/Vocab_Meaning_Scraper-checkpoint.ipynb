# %%
import pandas as pd
import numpy as np

import requests

from bs4 import BeautifulSoup

from selenium import webdriver
import re

from pdfquery import PDFQuery

import warnings; warnings.filterwarnings('ignore')

# %%
df = pd.read_excel(r"GregMat_list_with_MEANING.xlsx","Sheet1")
renamer = [[0,1],[9,10],[17,18]]
df

# %%
df_words = pd.DataFrame()
for i in range(len(renamer)):
    print(renamer[i])
    df_temp = df.iloc[:,renamer[i]].dropna(how='all')
    df_temp.columns = ['WORD', 'MEANING']
    df_words = df_words.append(df_temp)

# %%
df_words['GROUP'] = df_words['WORD'].apply(lambda x: x if 'Group ' in str(x) else np.nan)
df_words[['WORD','GROUP']] = df_words[['WORD','GROUP']].fillna(method = 'ffill')
df_words = df_words[df_words['WORD'].apply(lambda x: x.split()[0] not in ['Group','Take','Word'])]
df_words2 = df_words.dropna(how = 'any').groupby(['GROUP','WORD'])['MEANING'].apply(lambda x: "\n".join(x)).reset_index()
df_words2['GROUP NO'] = df_words2['GROUP'].apply(lambda x: int(x.split()[-1]))
df_words2['GROUP'].value_counts()

# %%
df_words2

# %%
def pdf_words(pdf_file):
    pdf = PDFQuery(pdf_file)
    pdf.load()

    # Use CSS-like selectors to locate the elements
    text_elements = pdf.pq('LTTextLineHorizontal')

    # Extract the text from the elements
    text = [t.text for t in text_elements]
    set_no = text[0]
    print(set_no)
    lines = []
    for line in text:
        if len(line.strip())==0: continue
        if 'http' in line.lower(): continue
        if line.split()[0]=='Set': continue

        if len(re.sub("[0-9.]","", line.split()[0]).strip())==0:
            lines.append(line)
        else:
            lines[len(lines)-1] = lines[len(lines)-1] + line

#     for line in lines:
#         print(line)
    
    lines_pdf = pd.DataFrame(lines, columns = ['WORD:Mean'])
    lines_pdf['WORD'] = lines_pdf['WORD:Mean'].apply(lambda x: re.sub("[^a-z]","",str(x).split()[1].lower()))
    lines_pdf['MEANING'] = lines_pdf.apply(lambda x: str(x['WORD:Mean']).split(x['WORD'])[-1][2:].strip(), axis=1)
    
    lines_pdf['GROUP'] = 'Group ' + set_no.split()[-1]
    return lines_pdf[['GROUP','WORD','MEANING']]
pdf_file = '900.pdf'
pdf_df = pdf_words(pdf_file)
pdf_df

# %%
driver = webdriver.Chrome(r"C:/Users/70049282/VIA/GRE_Vocab_Scraper/chromedriver.exe")
url = r"https://quizlet.com/in/608598734/all-900-words-gregmat-group-1-to-30-flash-cards/"
driver.get(url)

for button in driver.find_elements_by_tag_name("button"):
    button_text = button.text
    if button.text.strip().title() == 'See More':
        print(button.text)
        button.click()
        break

text = driver.find_element_by_tag_name('body').text
driver.close()

# %%
text.split("\n")[:5]

# %%
sentences = text.split("\n")

lines = sentences[sentences.index('Terms in this set (900)')+1:sentences.index('Flickr Creative Commons Images')]

lines[:20]

# %%
word_meaning_dict = {lines[0]:''}
lines2 = ''
word = lines[0]
multi_count=0
for line in lines[1:]:    
    if line.strip()=='':        
        continue

    if ' ' not in line.strip():
        lines2 = lines2 + "|||" + word + ":::"
        if word_meaning_dict[word]=='':
            word_meaning_dict[word]+=line.strip()
        else:    
            word = line
            word_meaning_dict[word] = ''
            
        
        
    else:
        word_meaning_dict[word] += line.strip()
        lines2 = lines2 + line + "\n"
        

    
word_df = pd.DataFrame(word_meaning_dict.items(), columns = ['WORD','MEANING'])
# word_meaning_dict['belie']

# %%
word_df

# %%
word_df.to_excel(r"Test.xlsx", index = False)
word_df.iloc[25:40,:]

# %%
# driver = webdriver.Chrome("C:/Users/Admin/Desktop/GREGMAT PREP/chromedriver.exe")
# driver.get(url)
# text = driver.find_element_by_tag_name('body').text

def text_miner(word):
    print(word)
    print(word_meaning_dict[word])
    print("\n")
    url = f'https://www.google.com/search?q={word}%20word%20meaning#dobc=en'

    response = requests.get(url, verify = False)
    a = response.text
    soup = BeautifulSoup(a, 'html.parser')
    text = soup.get_text()
    return text

# %%
word_df['GOOGLE_TEXT'] = word_df['WORD'].apply(text_miner)
word_df

# %%
word_df.to_excel(r"Test.xlsx", index = False)

# %%
word_df = pd.read_excel(r"C:\Users\70049282\VIA\GRE_Vocab_Scraper\Test.xlsx")

def synonym_mining(word_s):
    word_dict = dict(word_s)
    
    if word_dict['syn_flag']:
        sent = re.sub("synonyms:","==>",word_dict['GOOGLE_TEXT2'])
        sent2 = [i for i in sent.split("\n") if "==>" in i]
        ex_syn  = {x.split("==>")[1].strip():x.split("==>")[0].strip().split(".",1) for x in sent2}
        
        syn = "\n".join([str(i+1) + ". " + j for i,j in enumerate(ex_syn.keys())])
        ex = "\n\n".join([str(i+1) + ". " + j[0] + "\n" + j[1]  for i,j in enumerate(ex_syn.values())])
        if len(ex_syn)==1:
            return (syn[3:], ex[3:])
        else:
            return (syn, ex)
    else:
        sent = word_dict['GOOGLE_TEXT2'].split("\n")[-1]
        ex_dict = {x.split(".")[-2].strip():x.split(".")[-1].strip() for x in sent.split("\n")}
        ex = "\n\n".join([str(i+1) + ". " + j[0] + "\n" + j[1]  for i,j in enumerate(ex_dict.items())])
        if len(ex_dict)==1:
            return (np.nan, ex[3:])
        else:
            return (np.nan, ex)
        
word_df['syn_flag'] = word_df['GOOGLE_TEXT2'].apply(lambda x: 'synonyms:' in x)
word_df['SYNONYMS_EXAMPLE'] = word_df.apply(lambda x: synonym_mining(x), axis=1)
word_df['SYNONYMS'] = word_df['SYNONYMS_EXAMPLE'].apply(lambda x: x[0])
word_df['EXAMPLE'] = word_df['SYNONYMS_EXAMPLE'].apply(lambda x: x[1])
word_df
# Out:
#           WORD                                            MEANING  \
# 0       abound                 exist in large numbers or amounts.
# 1    amorphous           without a clearly defined shape or form.
# 2         Poll             What's your jam during study sessions?
# 3     Podcasts  Lo-fi groovesSweet silenceMy curated playlists...
# 4      austere  1. Strict in manner2. Lack of comforts or luxu...
# ..         ...                                                ...
# 896   cogitate                                    to think deeply
# 897    nominal  (adj.) existing in name only, not real; too sm...
# 898     plucky                                 courageous; spunky
# 899     grovel  (v) to humble oneself, act in a fearful and se...
# 900      feint  (n.) a deliberately deceptive movement; a pret...
#
#                                            GOOGLE_TEXT  syn_flag  \
# 0    abound word meaning - Google SearchGoogle×Plea...      True
# 1    amorphous word meaning - Google SearchGoogle×P...      True
# 2    Poll word meaning - Google SearchGoogle×Please...      True
# 3    Podcasts word meaning - Google SearchGoogle×Pl...     False
# 4    austere word meaning - Google SearchGoogle×Ple...      True
# ..                                                 ...       ...
# 896  cogitate word meaning - Google SearchGoogle×Pl...      True
# 897  nominal word meaning - Google SearchGoogle×Ple...      True
# 898  plucky word meaning - Google SearchGoogle×Plea...      True
# 899  grovel word meaning - Google SearchGoogle×Plea...      True
# 900  feint word meaning - Google SearchGoogle×Pleas...     False
#
#                                           GOOGLE_TEXT2  \
# 0    abound word meaning - Google SearchGoogle×Plea...
# 1    amorphous word meaning - Google SearchGoogle×P...
# 2    Poll word meaning - Google SearchGoogle×Please...
# 3    Podcasts word meaning - Google SearchGoogle×Pl...
# 4    austere word meaning - Google SearchGoogle×Ple...
# ..                                                 ...
# 896  cogitate word meaning - Google SearchGoogle×Pl...
# 897  nominal word meaning - Google SearchGoogle×Ple...
# 898  plucky word meaning - Google SearchGoogle×Plea...
# 899  grovel word meaning - Google SearchGoogle×Plea...
# 900  feint word meaning - Google SearchGoogle×Pleas...
#
#                                       SYNONYMS_EXAMPLE  \
# 0    (be plentiful, be abundant, be numerous, proli...
# 1    (shapeless, formless, unformed, unshaped, stru...
# 2    (1. vote, ballot, show of hands, straw vote/po...
# 3    (nan, make (a digital audio file) available as...
# 4    (severe, stern, strict, harsh, unfeeling, ston...
# ..                                                 ...
# 896  (think (about), contemplate, consider, give th...
# 897  (in name/title only, titular, formal, official...
# 898  (brave, courageous, bold, daring, fearless, in...
# 899  (crawl, creep, cringe, crouch, prostrate onese...
# 900  (nan, make a deceptive or distracting movement...
#
#                                               SYNONYMS  \
# 0    be plentiful, be abundant, be numerous, prolif...
# 1    shapeless, formless, unformed, unshaped, struc...
# 2    1. vote, ballot, show of hands, straw vote/pol...
# 3                                                  NaN
# 4    severe, stern, strict, harsh, unfeeling, stony...
# ..                                                 ...
# 896  think (about), contemplate, consider, give tho...
# 897  in name/title only, titular, formal, official,...
# 898  brave, courageous, bold, daring, fearless, int...
# 899  crawl, creep, cringe, crouch, prostrate onesel...
# 900                                                NaN
#
#                                                EXAMPLE
# 0    exist in large numbers or amounts\n'rumours of...
# 1    without a clearly defined shape or form\n'an a...
# 2    1. the process of voting in an election\n'the ...
# 3    make (a digital audio file) available as a pod...
# 4    severe or strict in manner or attitude\n'he wa...
# ..                                                 ...
# 896  think deeply about something; meditate or refl...
# 897  (of a role or status) existing in name only\n'...
# 898  having or showing determined courage in the fa...
# 899  lie or crawl abjectly on the ground with one's...
# 900  make a deceptive or distracting movement, espe...
#
# [901 rows x 8 columns]

# %%
word = "exhilarating"
word_df[word_df['WORD']==word]['SYNONYMS_EXAMPLE'].iloc[0]
# Out:
# (nan,
#  "making one feel very happy, animated, or elated; thrilling\n'an exhilarating two-hour rafting experience'")

# %%
word_df.to_excel("Test.xlsx", index = False)

# %%
word_df_final = pd.read_excel(r"Test.xlsx")
word_df_final = word_df_final[word_df_final['WORD'].apply(lambda x: re.sub("[a-z]","",x)=='')]
word_df_final = word_df_final[['WORD','MEANING','SYNONYMS','EXAMPLE']].drop_duplicates().reset_index(drop = True).reset_index()
word_df_final['GROUP'] = word_df_final['index'].apply(lambda x: x//30+1)
word_df_final[['GROUP','WORD','MEANING','SYNONYMS','EXAMPLE']].to_excel("Final Words.xlsx", index = False)
word_df_final
# Out:
#      index        WORD                                            MEANING  \
# 0        0      abound                 exist in large numbers or amounts.
# 1        1   amorphous           without a clearly defined shape or form.
# 2        2     austere  1. Strict in manner2. Lack of comforts or luxu...
# 3        3       belie  1. (of an appearance) fail to give a true impr...
# 4        4  capricious  given to sudden and unaccountable changes of m...
# ..     ...         ...                                                ...
# 892    892    cogitate                                    to think deeply
# 893    893     nominal  (adj.) existing in name only, not real; too sm...
# 894    894      plucky                                 courageous; spunky
# 895    895      grovel  (v) to humble oneself, act in a fearful and se...
# 896    896       feint  (n.) a deliberately deceptive movement; a pret...
#
#                                               SYNONYMS  \
# 0    be plentiful, be abundant, be numerous, prolif...
# 1    shapeless, formless, unformed, unshaped, struc...
# 2    severe, stern, strict, harsh, unfeeling, stony...
# 3    contradict, be at odds with, call into questio...
# 4    fickle, inconstant, changeable, variable, unst...
# ..                                                 ...
# 892  think (about), contemplate, consider, give tho...
# 893  in name/title only, titular, formal, official,...
# 894  brave, courageous, bold, daring, fearless, int...
# 895  crawl, creep, cringe, crouch, prostrate onesel...
# 896                                                NaN
#
#                                                EXAMPLE  GROUP
# 0    exist in large numbers or amounts\n'rumours of...      1
# 1    without a clearly defined shape or form\n'an a...      1
# 2    severe or strict in manner or attitude\n'he wa...      1
# 3    (of an appearance) fail to give a true impress...      1
# 4    given to sudden and unaccountable changes of m...      1
# ..                                                 ...    ...
# 892  think deeply about something; meditate or refl...     30
# 893  (of a role or status) existing in name only\n'...     30
# 894  having or showing determined courage in the fa...     30
# 895  lie or crawl abjectly on the ground with one's...     30
# 896  make a deceptive or distracting movement, espe...     30
#
# [897 rows x 6 columns]

# %%
# Out:
#      index       WORD                                            MEANING  \
# 0        0     abound                 exist in large numbers or amounts.
# 1        1  amorphous           without a clearly defined shape or form.
# 2        2       Poll             What's your jam during study sessions?
# 3        3   Podcasts  Lo-fi groovesSweet silenceMy curated playlists...
# 4        4    austere  1. Strict in manner2. Lack of comforts or luxu...
# ..     ...        ...                                                ...
# 896    896   cogitate                                    to think deeply
# 897    897    nominal  (adj.) existing in name only, not real; too sm...
# 898    898     plucky                                 courageous; spunky
# 899    899     grovel  (v) to humble oneself, act in a fearful and se...
# 900    900      feint  (n.) a deliberately deceptive movement; a pret...
#
#                                               SYNONYMS  \
# 0    be plentiful, be abundant, be numerous, prolif...
# 1    shapeless, formless, unformed, unshaped, struc...
# 2    1. vote, ballot, show of hands, straw vote/pol...
# 3                                                  NaN
# 4    severe, stern, strict, harsh, unfeeling, stony...
# ..                                                 ...
# 896  think (about), contemplate, consider, give tho...
# 897  in name/title only, titular, formal, official,...
# 898  brave, courageous, bold, daring, fearless, int...
# 899  crawl, creep, cringe, crouch, prostrate onesel...
# 900                                                NaN
#
#                                                EXAMPLE  Group No  GROUP
# 0    exist in large numbers or amounts\n'rumours of...         1      1
# 1    without a clearly defined shape or form\n'an a...         1      1
# 2    1. the process of voting in an election\n'the ...         1      1
# 3    make (a digital audio file) available as a pod...         1      1
# 4    severe or strict in manner or attitude\n'he wa...         1      1
# ..                                                 ...       ...    ...
# 896  think deeply about something; meditate or refl...        30     30
# 897  (of a role or status) existing in name only\n'...        30     30
# 898  having or showing determined courage in the fa...        30     30
# 899  lie or crawl abjectly on the ground with one's...        30     30
# 900  make a deceptive or distracting movement, espe...        31     31
#
# [901 rows x 7 columns]
